# %%
import pandas as pd
import numpy as np
import ast
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

# %%
try:
    city = pd.read_csv('City.csv', encoding='latin-1')
except UnicodeDecodeError:
    try:
        city = pd.read_csv('City.csv', encoding='cp1252')  
    except UnicodeDecodeError:
        
        print("Error: Unable to decode file with available encodings.")
        
try:
    state_with_places = pd.read_csv('State_with_places.csv', encoding='latin-1')
except UnicodeDecodeError:
    try:
        state_with_places = pd.read_csv('State_with_places.csv', encoding='cp1252')  
    except UnicodeDecodeError:
        
        print("Error: Unable to decode file with available encodings.")

try:
    indian_tourism = pd.read_csv('India-Tourism-Statistics-2021-Table-5.2.3.csv', encoding='latin-1')
except UnicodeDecodeError:
    try:
        indian_tourism = pd.read_csv('India-Tourism-Statistics-2021-Table-5.2.3.csv', encoding='cp1252')  
    except UnicodeDecodeError:
        
        print("Error: Unable to decode file with available encodings.")

try:
    india = pd.read_csv('india.csv', encoding='latin-1')
except UnicodeDecodeError:
    try:
        india = pd.read_csv('india.csv', encoding='cp1252')  
    except UnicodeDecodeError:
        
        print("Error: Unable to decode file with available encodings.")

try:
    indian_cities = pd.read_csv('Indian Cities Database.csv', encoding='latin-1')
except UnicodeDecodeError:
    try:
        indian_cities = pd.read_csv('Indian Cities Database.csv', encoding='cp1252')  
    except UnicodeDecodeError:
        
        print("Error: Unable to decode file with available encodings.")

# %%
city
# Out:
#            City  Ratings Ideal_duration    Best_time_to_visit  \
# 0        Manali      4.5            2-4          October-June
# 1    Leh Ladakh      4.6            5-7           JulyOctober
# 2         Coorg      4.2            2-3        September-June
# 3       Andaman      4.5            4-6         October-March
# 4   Lakshadweep      4.0            4-6    September-February
# ..          ...      ...            ...                   ...
# 95      Pushkar      4.0            1-2  October and November
# 96  Chittorgarh      4.1              1       October - March
# 97        Nahan      3.9            1-2          April - June
# 98       Lavasa      3.9              1      June and October
# 99       Poovar      4.3              1      June - September
#
#                                             City_desc
# 0   [' One of the most popular hill stations in Hi...
# 1   [" Ladakh is a union territory in the Kashmir ...
# 2   [' Located amidst imposing mountains in Karnat...
# ...

# %%
state_with_places.head()
# Out:
#                State                                    Places_to_Visit  \
# 0     Andhra Pradesh  Charminar, Araku Valley, Amaravati, Borra Cave...
# 1  Arunachal Pradesh  Tawang Monastery, Namdapha National Park, Ziro...
# 2              Assam  Kaziranga National Park, Kamakhya Temple, Mana...
# 3              Bihar  Bodh Gaya, Mahabodhi Temple, Nalanda Universit...
# 4       Chhattisgarh  Kailashnath Temple, Bastar Hills, Chitrakote F...
#
#         Category         Peak Season   @
# 0     Historical     October - March NaN
# 1      Religious  October - February NaN
# 2  National Park     October - April NaN
# 3      Religious     October - March NaN
# 4      Religious     October - March NaN

# %%
indian_tourism.head()
# Out:
#   Circle Name of the Monument   Domestic-2019-20  Foreign-2019-20  \
# 0   Agra             Taj Mahal           4429710           645415
# 1   Agra             Agra Fort           1627154           386522
# 2   Agra        Fatehpur Sikri            454376           184751
# 3   Agra   Akbar Tomb Sikandra            229270            19625
# 4   Agra  Mariam tomb Sikandra             22517              414
#
#    Domestic-2020-21  Foreign-2020-21  % Growth 2021-21/2019-20-Domestic  \
# 0           1259892             9034                             -71.56
# 1            371242             2810                             -77.18
# 2            107835              574                             -76.27
# 3             99509              321                             -56.60
# 4              9765               31                             -56.63
#
#    % Growth 2021-21/2019-20-Foreign
# 0                            -98.60
# 1                            -99.27
# ...

# %%
india
# Out:
#              Place Name  Rating  \
# 0            Aurangabad     3.3
# 1                 Jammu     3.6
# 2              Dehradun     3.3
# 3                  Puri     4.0
# 4           Cherrapunji     4.0
# ..                  ...     ...
# 95                 Pune     3.3
# 96           Kodaikanal     4.4
# 97                Kochi     3.8
# 98            Ahmedabad     3.3
# 99  Kanha National Park     3.5
#
#                                           About Place   Best Time To Visit
# 0   Aurangabad, which was declared by the Governme...     October to March
# 1   Jammu is the southernmost-part of the union te...   September to March
# 2   Nestled amidst the Doon Valley in the state of...  Throughout the year
# 3   Puri in Odisha is one of the four must-visit p...        July to March
# 4   Earlier the wettest place on the Earth, Cherra...     September to May
# ..                                                ...                  ...
# ...

# %%
indian_cities
# Out:
#              City        Lat       Long country iso2           State
# 0          Abohar  30.144533  74.195520   India   IN          Punjab
# 1        Adilabad  19.400000  78.310000   India   IN       Telangana
# 2        Agartala  23.836049  91.279386   India   IN         Tripura
# 3            Agra  27.187935  78.003944   India   IN   Uttar Pradesh
# 4      Ahmadnagar  19.094571  74.738432   India   IN     Maharashtra
# ..            ...        ...        ...     ...  ...             ...
# 208  Vizianagaram  18.113290  83.397743   India   IN  Andhra Pradesh
# 209      Warangal  17.978423  79.600209   India   IN       Telangana
# 210    Jorapokhar  23.700000  86.412670   India   IN       Jharkhand
# 211  Brajrajnagar  21.820000  83.920000   India   IN          Odisha
# 212       Talcher  20.950000  85.230000   India   IN          Odisha
#
# [213 rows x 6 columns]

# %%
indian_cities_wih_rating=city.merge(indian_cities,on='City')
indian_cities_wih_rating=indian_cities_wih_rating.drop(['Lat','Long','iso2'],axis=1)
indian_cities_wih_rating
# Out:
#           City  Ratings Ideal_duration      Best_time_to_visit  \
# 0      Udaipur      4.3            2-3           October-March
# 1     Srinagar      4.5            3-5           April-October
# 2      Gangtok      4.4            2-4              March-June
# 3       Shimla      4.2            2-4              March-June
# 4       Jaipur      4.4            2-3          November-March
# 5     Varanasi      4.5            2-3           October-March
# 6       Mumbai      4.2            3-5        October-February
# 7         Agra      4.2            1-2    November to February
# 8      Jodhpur      4.2            1-2    November to February
# 9     Amritsar      4.4            2-3           October-March
# 10       Delhi      4.1            3-5            OctoberMarch
# 11   Hyderabad      4.1            2-4  November to February
# 12     Chennai      3.9            2-3     October to February
# 13        Pune      4.1            1-3     October to February
# ...

# %%
new_city=city
new=new_city.drop('City_description',axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[56], line 2
#       1 new_city=city
# ----> 2 new=new_city.drop('City_description',axis=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
# ...
